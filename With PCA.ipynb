# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\Data Science With Python\dataset\Linear dataset\practiceDataset.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dines\AppData\Local\Temp\ipykernel_1880\1334281446.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv("D:\Data Science With Python\dataset\Linear dataset\practiceDataset.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
df['LotFrontage']=imputer.fit_transform(df[['LotFrontage']])
df['MasVnrArea']=imputer.fit_transform(df[['MasVnrArea']])
df['GarageYrBlt']=imputer.fit_transform(df[['GarageYrBlt']])
df['LotFrontage']=imputer.fit_transform(df[['LotFrontage']])

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
df['Alley']=imputer.fit_transform(df[['Alley']]).ravel()
df['MasVnrType']=imputer.fit_transform(df[['MasVnrType']]).ravel()
df['BsmtCond']=imputer.fit_transform(df[['BsmtCond']]).ravel()
df['BsmtQual']=imputer.fit_transform(df[['BsmtQual']]).ravel()
df['BsmtExposure']=imputer.fit_transform(df[['BsmtExposure']]).ravel()
df['BsmtFinType1']=imputer.fit_transform(df[['BsmtFinType1']]).ravel()
df['BsmtFinType2']=imputer.fit_transform(df[['BsmtFinType2']]).ravel()
df['FireplaceQu']=imputer.fit_transform(df[['FireplaceQu']]).ravel()
df['GarageType']=imputer.fit_transform(df[['GarageType']]).ravel()
df['GarageFinish']=imputer.fit_transform(df[['GarageFinish']]).ravel()
df['GarageQual']=imputer.fit_transform(df[['GarageQual']]).ravel()
df['GarageCond']=imputer.fit_transform(df[['GarageCond']]).ravel()
df['PoolQC']=imputer.fit_transform(df[['PoolQC']]).ravel()
df['Fence']=imputer.fit_transform(df[['Fence']]).ravel()
df['MiscFeature']=imputer.fit_transform(df[['MiscFeature']]).ravel()
df['Electrical']=imputer.fit_transform(df[['Electrical']]).ravel()
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
object=df.select_dtypes(include='object')
object.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# List of object columns to encode
object_cols = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
               'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
               'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
               'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
               'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
               'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
               'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
               'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
               'SaleType', 'SaleCondition']

# Apply LabelEncoder to each column
le = LabelEncoder()
for col in object_cols:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1      0         3
# 1   2          20         3         80.0     9600       1      0         3
# 2   3          60         3         68.0    11250       1      0         0
# 3   4          70         3         60.0     9550       1      0         0
# 4   5          60         3         84.0    14260       1      0         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            3          0  ...         0       2      2            2        0
# 1            3          0  ...         0       2      2            2        0
# 2            3          0  ...         0       2      2            2        0
# 3            3          0  ...         0       2      2            2        0
# 4            3          0  ...         0       2      2            2        0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
x=df
st=StandardScaler()
x_scaled=st.fit_transform(x)
x_scaled
# Out:
# array([[-1.73086488,  0.07337496, -0.04553194, ...,  0.31386709,
#          0.2085023 ,  0.34727322],
#        [-1.7284922 , -0.87256276, -0.04553194, ...,  0.31386709,
#          0.2085023 ,  0.00728832],
#        [-1.72611953,  0.07337496, -0.04553194, ...,  0.31386709,
#          0.2085023 ,  0.53615372],
#        ...,
#        [ 1.72611953,  0.30985939, -0.04553194, ...,  0.31386709,
#          0.2085023 ,  1.07761115],
#        [ 1.7284922 , -0.87256276, -0.04553194, ...,  0.31386709,
#          0.2085023 , -0.48852299],
#        [ 1.73086488, -0.87256276, -0.04553194, ...,  0.31386709,
#          0.2085023 , -0.42084081]], shape=(1460, 81))

# %%
input=df.drop('SalePrice',axis=1)
output=df['SalePrice']
input
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         3         65.0     8450       1      0
# 1        2          20         3         80.0     9600       1      0
# 2        3          60         3         68.0    11250       1      0
# 3        4          70         3         60.0     9550       1      0
# 4        5          60         3         84.0    14260       1      0
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60         3         62.0     7917       1      0
# 1456  1457          20         3         85.0    13175       1      0
# 1457  1458          70         3         66.0     9042       1      0
# 1458  1459          20         3         68.0     9717       1      0
# 1459  1460          20         3         75.0     9937       1      0
#
#       LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=40)    
x_pca=pca.fit_transform(x_scaled)
x_pca
# Out:
# array([[ 2.09178883, -0.1128399 , -1.85262167, ..., -0.03907039,
#         -0.56983741, -0.49447306],
#        [ 0.23338189, -1.4630431 ,  1.92134625, ..., -0.30670679,
#         -1.00674426,  0.1658332 ],
#        [ 2.63229511, -0.10158953, -1.25395125, ...,  0.44130524,
#          0.3412933 , -0.97414941],
#        ...,
#        [ 1.43634441,  2.99470539,  0.10000732, ...,  0.13543335,
#         -1.82657818, -1.30400803],
#        [-3.0121739 , -2.24718746,  2.53789354, ...,  1.47260771,
#          0.32354757, -0.04201621],
#        [-0.91834395, -2.13550275,  2.29359451, ...,  1.10106223,
#          0.71272843,  0.9207566 ]], shape=(1460, 40))

# %%
print("egenvalues")
print(pca.explained_variance_)
print("eigenvectors")
print(pca.components_)
# Out:
# egenvalues
# [11.26388284  4.08094682  3.820695    3.01590202  2.36157379  2.07119329
#   1.96173119  1.87483341  1.7655566   1.69402381  1.60066134  1.53642046
#   1.47109476  1.3866012   1.36675537  1.32060245  1.26196825  1.21528928
#   1.13744593  1.13126223  1.11964424  1.11414934  1.08561323  1.08249883
#   1.0725173   1.02998534  0.99666725  0.97728933  0.95190755  0.94063843
#   0.90075926  0.8861356   0.87637157  0.84903353  0.83712021  0.81391964
#   0.78695735  0.77970157  0.76753042  0.7474824 ]
# eigenvectors
# [[-0.00210404 -0.01027726 -0.07691577 ... -0.01912793  0.0725213
#    0.26261982]
#  [ 0.00722609  0.0386906   0.0323536  ...  0.00412742 -0.02457174
#    0.06107691]
#  [-0.00662272 -0.21801784  0.08263444 ...  0.00163151 -0.06188842
#    0.07968668]
#  ...
#  [ 0.01334596 -0.07340281 -0.02550131 ...  0.44147985 -0.37268228
#    0.01421918]
#  [-0.05347969  0.02911695 -0.02917667 ... -0.15007979  0.15887434
#   -0.02087083]
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.plot(pca.explained_variance_,marker='o')
plt.show()

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=11)
x=pca.fit_transform(x_scaled)
y_sklearn=pca.fit_transform(x_scaled)
y_sklearn
# Out:
# array([[ 2.09178883, -0.1128399 , -1.85262167, ...,  0.00301223,
#         -1.1041821 ,  0.45924619],
#        [ 0.23338189, -1.4630431 ,  1.92134625, ..., -0.8717978 ,
#          0.23260106, -0.02034872],
#        [ 2.63229511, -0.10158953, -1.25395125, ..., -0.32850554,
#         -0.87459795,  0.43047466],
#        ...,
#        [ 1.43634441,  2.99470539,  0.10000732, ...,  0.7489302 ,
#          0.15878248, -0.37393246],
#        [-3.0121739 , -2.24718746,  2.53789354, ...,  2.27597498,
#          2.62772109,  0.41228657],
#        [-0.91834395, -2.13550275,  2.29359451, ...,  0.45284809,
#          0.86074176,  0.77678054]], shape=(1460, 11))

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(y_sklearn,output,random_state=42,test_size=0.2)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)                      
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.8091788079386819

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(y_sklearn,output,random_state=42,test_size=0.2)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_test,y_test)                      
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.8350768116716436
